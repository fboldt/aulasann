# %%
# !pip install keras-tuner -q

# %%
from tensorflow import keras
from tensorflow.keras import layers

def build_model(hp):
    units = hp.Int(name="units", min_value=16, max_value=64, step=16)
    model = keras.Sequential([
        layers.Dense(units, activation="relu"),
        layers.Dense(10, activation="softmax")
    ])
    optimizer = hp.Choice(name="optimizer", values=["rmsprop", "adam"])
    model.compile(
        optimizer=optimizer,
        loss="sparse_categorical_crossentropy",
        metrics=["accuracy"])
    return model
# Out:
# 2023-06-26 16:59:37.537199: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-06-26 16:59:38.100428: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
# !pip install keras-tuner[bayesian]

# %%
import keras_tuner as kt

tuner = kt.BayesianOptimization(
    build_model,
    objective="val_accuracy",
    max_trials=100,
    executions_per_trial=2,
    directory="mnist_kt_test",
    overwrite=True,
)
# Out:
# 2023-06-26 16:59:38.811521: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-06-26 16:59:38.828942: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-06-26 16:59:38.829291: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-06-26 16:59:38.830223: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-06-26 16:59:38.830565: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-06-26 16:59:38.830857: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-06-26 16:59:39.286627: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-06-26 16:59:39.286993: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-06-26 16:59:39.287279: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-06-26 16:59:39.287542: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1635] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 10139 MB memory:  -> device: 0, name: NVIDIA TITAN V, pci bus id: 0000:01:00.0, compute capability: 7.0

# %%
tuner.search_space_summary()
# Out:
# Search space summary
# Default search space size: 2
# units (Int)
# {'default': None, 'conditions': [], 'min_value': 16, 'max_value': 64, 'step': 16, 'sampling': 'linear'}
# optimizer (Choice)
# {'default': 'rmsprop', 'conditions': [], 'values': ['rmsprop', 'adam'], 'ordered': False}

# %%
(x_train, y_train), (x_test, y_test) = keras.datasets.mnist.load_data()
x_train = x_train.reshape((-1, 28 * 28)).astype("float32") / 255
x_test = x_test.reshape((-1, 28 * 28)).astype("float32") / 255
x_train_full = x_train[:]
y_train_full = y_train[:]
num_val_samples = 10000
x_train, x_val = x_train[:-num_val_samples], x_train[-num_val_samples:]
y_train, y_val = y_train[:-num_val_samples], y_train[-num_val_samples:]
callbacks = [
    keras.callbacks.EarlyStopping(monitor="val_loss", patience=5),
]
tuner.search(
    x_train, y_train,
    batch_size=128,
    epochs=100,
    validation_data=(x_val, y_val),
    callbacks=callbacks,
    verbose=2,
)
# Out:
# Trial 100 Complete [00h 00m 59s]
# val_accuracy: 0.974049985408783
#
# Best val_accuracy So Far: 0.9765499830245972
# Total elapsed time: 01h 45m 13s
# INFO:tensorflow:Oracle triggered exit

# %%
top_n = 4
best_hps = tuner.get_best_hyperparameters(top_n)

# %%
def get_best_epoch(hp):
    model = build_model(hp)
    callbacks=[
        keras.callbacks.EarlyStopping(
            monitor="val_loss", mode="min", patience=10)
    ]
    history = model.fit(
        x_train, y_train,
        validation_data=(x_val, y_val),
        epochs=100,
        batch_size=128,
        callbacks=callbacks)
    val_loss_per_epoch = history.history["val_loss"]
    best_epoch = val_loss_per_epoch.index(min(val_loss_per_epoch)) + 1
    print(f"Best epoch: {best_epoch}")
    return best_epoch

# %%
def get_best_trained_model(hp):
    best_epoch = get_best_epoch(hp)
    model = build_model(hp)
    model.fit(
        x_train_full, y_train_full,
        batch_size=128, epochs=int(best_epoch * 1.2))
    return model

best_models = []
for hp in best_hps:
    model = get_best_trained_model(hp)
    model.evaluate(x_test, y_test)
    best_models.append(model)
# Out:
# Epoch 1/100
# 391/391 [==============================] - 2s 3ms/step - loss: 0.4523 - accuracy: 0.8784 - val_loss: 0.2370 - val_accuracy: 0.9341
# Epoch 2/100
# 391/391 [==============================] - 1s 4ms/step - loss: 0.2223 - accuracy: 0.9375 - val_loss: 0.1792 - val_accuracy: 0.9509
# Epoch 3/100
# 391/391 [==============================] - 1s 3ms/step - loss: 0.1734 - accuracy: 0.9500 - val_loss: 0.1524 - val_accuracy: 0.9574
# Epoch 4/100
# 391/391 [==============================] - 1s 2ms/step - loss: 0.1443 - accuracy: 0.9579 - val_loss: 0.1408 - val_accuracy: 0.9610
# Epoch 5/100
# 391/391 [==============================] - 1s 3ms/step - loss: 0.1239 - accuracy: 0.9637 - val_loss: 0.1266 - val_accuracy: 0.9645
# Epoch 6/100
# 391/391 [==============================] - 1s 3ms/step - loss: 0.1085 - accuracy: 0.9693 - val_loss: 0.1199 - val_accuracy: 0.9646
# Epoch 7/100
# 391/391 [==============================] - 2s 4ms/step - loss: 0.0953 - accuracy: 0.9719 - val_loss: 0.1144 - val_accuracy: 0.9672
# Epoch 8/100
# 391/391 [==============================] - 1s 3ms/step - loss: 0.0851 - accuracy: 0.9758 - val_loss: 0.1091 - val_accuracy: 0.9684
# Epoch 9/100
# 391/391 [==============================] - 2s 4ms/step - loss: 0.0760 - accuracy: 0.9773 - val_loss: 0.1034 - val_accuracy: 0.9698
# Epoch 10/100
# 391/391 [==============================] - 1s 4ms/step - loss: 0.0686 - accuracy: 0.9800 - val_loss: 0.1030 - val_accuracy: 0.9701
# Epoch 11/100
# 391/391 [==============================] - 1s 3ms/step - loss: 0.0618 - accuracy: 0.9820 - val_loss: 0.1011 - val_accuracy: 0.9710
# Epoch 12/100
# 391/391 [==============================] - 1s 3ms/step - loss: 0.0555 - accuracy: 0.9845 - val_loss: 0.0970 - val_accuracy: 0.9713
# Epoch 13/100
# 391/391 [==============================] - 1s 3ms/step - loss: 0.0505 - accuracy: 0.9856 - val_loss: 0.0970 - val_accuracy: 0.9727
# Epoch 14/100
# 391/391 [==============================] - 1s 3ms/step - loss: 0.0447 - accuracy: 0.9874 - val_loss: 0.0957 - val_accuracy: 0.9722
# Epoch 15/100
# 391/391 [==============================] - 1s 3ms/step - loss: 0.0410 - accuracy: 0.9887 - val_loss: 0.0973 - val_accuracy: 0.9715
# Epoch 16/100
# 391/391 [==============================] - 2s 5ms/step - loss: 0.0371 - accuracy: 0.9900 - val_loss: 0.0961 - val_accuracy: 0.9719
# Epoch 17/100
# 391/391 [==============================] - 1s 4ms/step - loss: 0.0343 - accuracy: 0.9908 - val_loss: 0.0954 - val_accuracy: 0.9722
# Epoch 18/100
# 391/391 [==============================] - 1s 4ms/step - loss: 0.0301 - accuracy: 0.9920 - val_loss: 0.0932 - val_accuracy: 0.9739
# Epoch 19/100
# 391/391 [==============================] - 1s 4ms/step - loss: 0.0275 - accuracy: 0.9927 - val_loss: 0.0932 - val_accuracy: 0.9724
# Epoch 20/100
# 391/391 [==============================] - 2s 4ms/step - loss: 0.0245 - accuracy: 0.9943 - val_loss: 0.0970 - val_accuracy: 0.9737
# Epoch 21/100
# 391/391 [==============================] - 2s 5ms/step - loss: 0.0223 - accuracy: 0.9947 - val_loss: 0.0972 - val_accuracy: 0.9734
# Epoch 22/100
# 391/391 [==============================] - 1s 3ms/step - loss: 0.0205 - accuracy: 0.9951 - val_loss: 0.0984 - val_accuracy: 0.9734
# Epoch 23/100
# 391/391 [==============================] - 1s 4ms/step - loss: 0.0185 - accuracy: 0.9959 - val_loss: 0.1001 - val_accuracy: 0.9722
# Epoch 24/100
# 391/391 [==============================] - 1s 3ms/step - loss: 0.0164 - accuracy: 0.9964 - val_loss: 0.1006 - val_accuracy: 0.9736
# Epoch 25/100
# 391/391 [==============================] - 1s 3ms/step - loss: 0.0147 - accuracy: 0.9972 - val_loss: 0.1021 - val_accuracy: 0.9726
# Epoch 26/100
# 391/391 [==============================] - 3s 7ms/step - loss: 0.0137 - accuracy: 0.9970 - val_loss: 0.1103 - val_accuracy: 0.9723
# Epoch 27/100
# 391/391 [==============================] - 1s 3ms/step - loss: 0.0120 - accuracy: 0.9977 - val_loss: 0.1032 - val_accuracy: 0.9734
# Epoch 28/100
# 391/391 [==============================] - 1s 4ms/step - loss: 0.0113 - accuracy: 0.9979 - val_loss: 0.1070 - val_accuracy: 0.9741
# Epoch 29/100
# 391/391 [==============================] - 2s 4ms/step - loss: 0.0095 - accuracy: 0.9987 - val_loss: 0.1033 - val_accuracy: 0.9753
# Best epoch: 19
# Epoch 1/22
# 469/469 [==============================] - 2s 3ms/step - loss: 0.4171 - accuracy: 0.8861
# Epoch 2/22
# 469/469 [==============================] - 2s 4ms/step - loss: 0.2047 - accuracy: 0.9421
# Epoch 3/22
# 469/469 [==============================] - 2s 4ms/step - loss: 0.1569 - accuracy: 0.9552
# Epoch 4/22
# 469/469 [==============================] - 1s 3ms/step - loss: 0.1278 - accuracy: 0.9637
# Epoch 5/22
# 469/469 [==============================] - 2s 4ms/step - loss: 0.1064 - accuracy: 0.9692
# Epoch 6/22
# 469/469 [==============================] - 2s 4ms/step - loss: 0.0916 - accuracy: 0.9742
# Epoch 7/22
# 469/469 [==============================] - 1s 3ms/step - loss: 0.0793 - accuracy: 0.9768
# Epoch 8/22
# 469/469 [==============================] - 1s 2ms/step - loss: 0.0702 - accuracy: 0.9799
# Epoch 9/22
# 469/469 [==============================] - 1s 2ms/step - loss: 0.0620 - accuracy: 0.9823
# Epoch 10/22
# 469/469 [==============================] - 1s 3ms/step - loss: 0.0548 - accuracy: 0.9841
# Epoch 11/22
# 469/469 [==============================] - 1s 2ms/step - loss: 0.0491 - accuracy: 0.9859
# Epoch 12/22
# 469/469 [==============================] - 1s 2ms/step - loss: 0.0442 - accuracy: 0.9875
# Epoch 13/22
# 469/469 [==============================] - 1s 2ms/step - loss: 0.0397 - accuracy: 0.9892
# Epoch 14/22
# 469/469 [==============================] - 1s 3ms/step - loss: 0.0361 - accuracy: 0.9899
# Epoch 15/22
# 469/469 [==============================] - 1s 3ms/step - loss: 0.0326 - accuracy: 0.9912
# Epoch 16/22
# 469/469 [==============================] - 1s 3ms/step - loss: 0.0292 - accuracy: 0.9922
# Epoch 17/22
# 469/469 [==============================] - 1s 2ms/step - loss: 0.0264 - accuracy: 0.9931
# Epoch 18/22
# 469/469 [==============================] - 1s 3ms/step - loss: 0.0241 - accuracy: 0.9938
# Epoch 19/22
# 469/469 [==============================] - 1s 3ms/step - loss: 0.0220 - accuracy: 0.9945
# Epoch 20/22
# 469/469 [==============================] - 1s 3ms/step - loss: 0.0194 - accuracy: 0.9955
# Epoch 21/22
# 469/469 [==============================] - 1s 2ms/step - loss: 0.0175 - accuracy: 0.9961
# Epoch 22/22
# 469/469 [==============================] - 1s 3ms/step - loss: 0.0163 - accuracy: 0.9961
# 313/313 [==============================] - 1s 1ms/step - loss: 0.0916 - accuracy: 0.9757
# Epoch 1/100
# 391/391 [==============================] - 2s 4ms/step - loss: 0.4672 - accuracy: 0.8717 - val_loss: 0.2403 - val_accuracy: 0.9335
# Epoch 2/100
# 391/391 [==============================] - 1s 3ms/step - loss: 0.2344 - accuracy: 0.9327 - val_loss: 0.1868 - val_accuracy: 0.9504
# Epoch 3/100
# 391/391 [==============================] - 1s 2ms/step - loss: 0.1816 - accuracy: 0.9476 - val_loss: 0.1582 - val_accuracy: 0.9569
# Epoch 4/100
# 391/391 [==============================] - 1s 3ms/step - loss: 0.1493 - accuracy: 0.9555 - val_loss: 0.1402 - val_accuracy: 0.9610
# Epoch 5/100
# 391/391 [==============================] - 1s 3ms/step - loss: 0.1258 - accuracy: 0.9639 - val_loss: 0.1256 - val_accuracy: 0.9662
# Epoch 6/100
# 391/391 [==============================] - 1s 3ms/step - loss: 0.1079 - accuracy: 0.9690 - val_loss: 0.1156 - val_accuracy: 0.9677
# Epoch 7/100
# 391/391 [==============================] - 1s 3ms/step - loss: 0.0960 - accuracy: 0.9717 - val_loss: 0.1113 - val_accuracy: 0.9679
# Epoch 8/100
# 391/391 [==============================] - 1s 3ms/step - loss: 0.0857 - accuracy: 0.9753 - val_loss: 0.1076 - val_accuracy: 0.9692
# Epoch 9/100
# 391/391 [==============================] - 1s 2ms/step - loss: 0.0768 - accuracy: 0.9774 - val_loss: 0.1098 - val_accuracy: 0.9701
# Epoch 10/100
# 391/391 [==============================] - 1s 4ms/step - loss: 0.0693 - accuracy: 0.9800 - val_loss: 0.1009 - val_accuracy: 0.9707
# Epoch 11/100
# 391/391 [==============================] - 1s 3ms/step - loss: 0.0620 - accuracy: 0.9820 - val_loss: 0.0977 - val_accuracy: 0.9712
# Epoch 12/100
# 391/391 [==============================] - 1s 4ms/step - loss: 0.0555 - accuracy: 0.9838 - val_loss: 0.0998 - val_accuracy: 0.9711
# Epoch 13/100
# 391/391 [==============================] - 1s 3ms/step - loss: 0.0516 - accuracy: 0.9857 - val_loss: 0.1015 - val_accuracy: 0.9710
# Epoch 14/100
# 391/391 [==============================] - 1s 3ms/step - loss: 0.0467 - accuracy: 0.9870 - val_loss: 0.0978 - val_accuracy: 0.9721
# Epoch 15/100
# 391/391 [==============================] - 1s 2ms/step - loss: 0.0419 - accuracy: 0.9885 - val_loss: 0.0952 - val_accuracy: 0.9731
# Epoch 16/100
# 391/391 [==============================] - 1s 3ms/step - loss: 0.0386 - accuracy: 0.9896 - val_loss: 0.0969 - val_accuracy: 0.9724
# Epoch 17/100
# 391/391 [==============================] - 1s 3ms/step - loss: 0.0350 - accuracy: 0.9908 - val_loss: 0.0986 - val_accuracy: 0.9727
# Epoch 18/100
# 391/391 [==============================] - 1s 3ms/step - loss: 0.0323 - accuracy: 0.9916 - val_loss: 0.0988 - val_accuracy: 0.9730
# Epoch 19/100
# 391/391 [==============================] - 1s 4ms/step - loss: 0.0298 - accuracy: 0.9920 - val_loss: 0.1017 - val_accuracy: 0.9728
# Epoch 20/100
# 391/391 [==============================] - 1s 3ms/step - loss: 0.0262 - accuracy: 0.9934 - val_loss: 0.0996 - val_accuracy: 0.9734
# Epoch 21/100
# 391/391 [==============================] - 1s 3ms/step - loss: 0.0242 - accuracy: 0.9940 - val_loss: 0.0988 - val_accuracy: 0.9733
# Epoch 22/100
# 391/391 [==============================] - 1s 3ms/step - loss: 0.0218 - accuracy: 0.9946 - val_loss: 0.0974 - val_accuracy: 0.9736
# Epoch 23/100
# 391/391 [==============================] - 1s 3ms/step - loss: 0.0194 - accuracy: 0.9958 - val_loss: 0.1012 - val_accuracy: 0.9727
# Epoch 24/100
# 391/391 [==============================] - 1s 3ms/step - loss: 0.0176 - accuracy: 0.9963 - val_loss: 0.1109 - val_accuracy: 0.9703
# Epoch 25/100
# 391/391 [==============================] - 1s 3ms/step - loss: 0.0173 - accuracy: 0.9960 - val_loss: 0.1058 - val_accuracy: 0.9718
# Best epoch: 15
# Epoch 1/18
# 469/469 [==============================] - 2s 3ms/step - loss: 0.4226 - accuracy: 0.8861
# Epoch 2/18
# 469/469 [==============================] - 1s 2ms/step - loss: 0.1983 - accuracy: 0.9446
# Epoch 3/18
# 469/469 [==============================] - 1s 2ms/step - loss: 0.1536 - accuracy: 0.9560
# Epoch 4/18
# 469/469 [==============================] - 1s 2ms/step - loss: 0.1247 - accuracy: 0.9642
# Epoch 5/18
# 469/469 [==============================] - 1s 2ms/step - loss: 0.1054 - accuracy: 0.9697
# Epoch 6/18
# 469/469 [==============================] - 1s 2ms/step - loss: 0.0917 - accuracy: 0.9738
# Epoch 7/18
# 469/469 [==============================] - 1s 2ms/step - loss: 0.0806 - accuracy: 0.9761
# Epoch 8/18
# 469/469 [==============================] - 1s 3ms/step - loss: 0.0712 - accuracy: 0.9794
# Epoch 9/18
# 469/469 [==============================] - 1s 3ms/step - loss: 0.0638 - accuracy: 0.9813
# Epoch 10/18
# 469/469 [==============================] - 1s 3ms/step - loss: 0.0577 - accuracy: 0.9827
# Epoch 11/18
# 469/469 [==============================] - 1s 3ms/step - loss: 0.0516 - accuracy: 0.9857
# Epoch 12/18
# 469/469 [==============================] - 2s 3ms/step - loss: 0.0466 - accuracy: 0.9866
# Epoch 13/18
# 469/469 [==============================] - 1s 2ms/step - loss: 0.0424 - accuracy: 0.9880
# Epoch 14/18
# 469/469 [==============================] - 1s 3ms/step - loss: 0.0390 - accuracy: 0.9892
# Epoch 15/18
# 469/469 [==============================] - 1s 2ms/step - loss: 0.0350 - accuracy: 0.9905
# Epoch 16/18
# 469/469 [==============================] - 1s 3ms/step - loss: 0.0317 - accuracy: 0.9916
# Epoch 17/18
# 469/469 [==============================] - 2s 3ms/step - loss: 0.0298 - accuracy: 0.9915
# Epoch 18/18
# 469/469 [==============================] - 1s 2ms/step - loss: 0.0261 - accuracy: 0.9933
# 313/313 [==============================] - 1s 1ms/step - loss: 0.0896 - accuracy: 0.9744
# Epoch 1/100
# 391/391 [==============================] - 2s 3ms/step - loss: 0.4632 - accuracy: 0.8750 - val_loss: 0.2449 - val_accuracy: 0.9301
# Epoch 2/100
# 391/391 [==============================] - 1s 3ms/step - loss: 0.2365 - accuracy: 0.9320 - val_loss: 0.1889 - val_accuracy: 0.9482
# Epoch 3/100
# 391/391 [==============================] - 1s 4ms/step - loss: 0.1827 - accuracy: 0.9467 - val_loss: 0.1578 - val_accuracy: 0.9571
# Epoch 4/100
# 391/391 [==============================] - 1s 3ms/step - loss: 0.1478 - accuracy: 0.9569 - val_loss: 0.1428 - val_accuracy: 0.9601
# Epoch 5/100
# 391/391 [==============================] - 1s 3ms/step - loss: 0.1234 - accuracy: 0.9640 - val_loss: 0.1254 - val_accuracy: 0.9656
# Epoch 6/100
# 391/391 [==============================] - 1s 3ms/step - loss: 0.1067 - accuracy: 0.9692 - val_loss: 0.1144 - val_accuracy: 0.9675
# Epoch 7/100
# 391/391 [==============================] - 2s 5ms/step - loss: 0.0920 - accuracy: 0.9734 - val_loss: 0.1105 - val_accuracy: 0.9682
# Epoch 8/100
# 391/391 [==============================] - 1s 2ms/step - loss: 0.0810 - accuracy: 0.9762 - val_loss: 0.1032 - val_accuracy: 0.9688
# Epoch 9/100
# 391/391 [==============================] - 1s 3ms/step - loss: 0.0725 - accuracy: 0.9790 - val_loss: 0.1026 - val_accuracy: 0.9690
# Epoch 10/100
# 391/391 [==============================] - 1s 3ms/step - loss: 0.0653 - accuracy: 0.9810 - val_loss: 0.1011 - val_accuracy: 0.9701
# Epoch 11/100
# 391/391 [==============================] - 1s 3ms/step - loss: 0.0576 - accuracy: 0.9831 - val_loss: 0.0978 - val_accuracy: 0.9708
# Epoch 12/100
# 391/391 [==============================] - 1s 3ms/step - loss: 0.0524 - accuracy: 0.9846 - val_loss: 0.0980 - val_accuracy: 0.9711
# Epoch 13/100
# 391/391 [==============================] - 1s 3ms/step - loss: 0.0479 - accuracy: 0.9866 - val_loss: 0.0957 - val_accuracy: 0.9718
# Epoch 14/100
# 391/391 [==============================] - 1s 3ms/step - loss: 0.0434 - accuracy: 0.9877 - val_loss: 0.0949 - val_accuracy: 0.9710
# Epoch 15/100
# 391/391 [==============================] - 1s 3ms/step - loss: 0.0389 - accuracy: 0.9890 - val_loss: 0.0937 - val_accuracy: 0.9719
# Epoch 16/100
# 391/391 [==============================] - 1s 3ms/step - loss: 0.0357 - accuracy: 0.9906 - val_loss: 0.0987 - val_accuracy: 0.9718
# Epoch 17/100
# 391/391 [==============================] - 1s 2ms/step - loss: 0.0318 - accuracy: 0.9917 - val_loss: 0.1061 - val_accuracy: 0.9704
# Epoch 18/100
# 391/391 [==============================] - 1s 3ms/step - loss: 0.0295 - accuracy: 0.9927 - val_loss: 0.0954 - val_accuracy: 0.9738
# Epoch 19/100
# 391/391 [==============================] - 1s 3ms/step - loss: 0.0265 - accuracy: 0.9936 - val_loss: 0.0971 - val_accuracy: 0.9719
# Epoch 20/100
# 391/391 [==============================] - 1s 3ms/step - loss: 0.0247 - accuracy: 0.9937 - val_loss: 0.0938 - val_accuracy: 0.9740
# Epoch 21/100
# 391/391 [==============================] - 1s 3ms/step - loss: 0.0219 - accuracy: 0.9948 - val_loss: 0.0946 - val_accuracy: 0.9732
# Epoch 22/100
# 391/391 [==============================] - 1s 3ms/step - loss: 0.0199 - accuracy: 0.9957 - val_loss: 0.0948 - val_accuracy: 0.9746
# Epoch 23/100
# 391/391 [==============================] - 1s 4ms/step - loss: 0.0188 - accuracy: 0.9956 - val_loss: 0.0982 - val_accuracy: 0.9738
# Epoch 24/100
# 391/391 [==============================] - 1s 3ms/step - loss: 0.0166 - accuracy: 0.9965 - val_loss: 0.0991 - val_accuracy: 0.9738
# Epoch 25/100
# 391/391 [==============================] - 1s 3ms/step - loss: 0.0154 - accuracy: 0.9967 - val_loss: 0.0990 - val_accuracy: 0.9752
# Best epoch: 15
# Epoch 1/18
# 469/469 [==============================] - 2s 2ms/step - loss: 0.4320 - accuracy: 0.8839
# Epoch 2/18
# 469/469 [==============================] - 1s 3ms/step - loss: 0.2066 - accuracy: 0.9412
# Epoch 3/18
# 469/469 [==============================] - 1s 2ms/step - loss: 0.1593 - accuracy: 0.9550
# Epoch 4/18
# 469/469 [==============================] - 1s 3ms/step - loss: 0.1308 - accuracy: 0.9632
# Epoch 5/18
# 469/469 [==============================] - 1s 3ms/step - loss: 0.1132 - accuracy: 0.9681
# Epoch 6/18
# 469/469 [==============================] - 1s 3ms/step - loss: 0.0996 - accuracy: 0.9717
# Epoch 7/18
# 469/469 [==============================] - 1s 3ms/step - loss: 0.0873 - accuracy: 0.9746
# Epoch 8/18
# 469/469 [==============================] - 1s 2ms/step - loss: 0.0779 - accuracy: 0.9774
# Epoch 9/18
# 469/469 [==============================] - 1s 2ms/step - loss: 0.0695 - accuracy: 0.9797
# Epoch 10/18
# 469/469 [==============================] - 1s 3ms/step - loss: 0.0630 - accuracy: 0.9822
# Epoch 11/18
# 469/469 [==============================] - 2s 3ms/step - loss: 0.0573 - accuracy: 0.9835
# Epoch 12/18
# 469/469 [==============================] - 1s 3ms/step - loss: 0.0515 - accuracy: 0.9851
# Epoch 13/18
# 469/469 [==============================] - 1s 3ms/step - loss: 0.0457 - accuracy: 0.9873
# Epoch 14/18
# 469/469 [==============================] - 1s 2ms/step - loss: 0.0425 - accuracy: 0.9883
# Epoch 15/18
# 469/469 [==============================] - 1s 3ms/step - loss: 0.0388 - accuracy: 0.9890
# Epoch 16/18
# 469/469 [==============================] - 1s 2ms/step - loss: 0.0357 - accuracy: 0.9900
# Epoch 17/18
# 469/469 [==============================] - 1s 2ms/step - loss: 0.0320 - accuracy: 0.9912
# Epoch 18/18
# 469/469 [==============================] - 1s 2ms/step - loss: 0.0293 - accuracy: 0.9919
# 313/313 [==============================] - 0s 1ms/step - loss: 0.0958 - accuracy: 0.9734
# Epoch 1/100
# 391/391 [==============================] - 2s 3ms/step - loss: 0.4549 - accuracy: 0.8774 - val_loss: 0.2351 - val_accuracy: 0.9350
# Epoch 2/100
# 391/391 [==============================] - 1s 3ms/step - loss: 0.2195 - accuracy: 0.9382 - val_loss: 0.1867 - val_accuracy: 0.9500
# Epoch 3/100
# 391/391 [==============================] - 1s 3ms/step - loss: 0.1712 - accuracy: 0.9508 - val_loss: 0.1556 - val_accuracy: 0.9551
# Epoch 4/100
# 391/391 [==============================] - 1s 2ms/step - loss: 0.1396 - accuracy: 0.9600 - val_loss: 0.1347 - val_accuracy: 0.9628
# Epoch 5/100
# 391/391 [==============================] - 1s 3ms/step - loss: 0.1182 - accuracy: 0.9663 - val_loss: 0.1241 - val_accuracy: 0.9649
# Epoch 6/100
# 391/391 [==============================] - 1s 3ms/step - loss: 0.1018 - accuracy: 0.9713 - val_loss: 0.1187 - val_accuracy: 0.9650
# Epoch 7/100
# 391/391 [==============================] - 1s 3ms/step - loss: 0.0892 - accuracy: 0.9747 - val_loss: 0.1120 - val_accuracy: 0.9673
# Epoch 8/100
# 391/391 [==============================] - 1s 3ms/step - loss: 0.0789 - accuracy: 0.9779 - val_loss: 0.1057 - val_accuracy: 0.9697
# Epoch 9/100
# 391/391 [==============================] - 1s 3ms/step - loss: 0.0706 - accuracy: 0.9798 - val_loss: 0.1022 - val_accuracy: 0.9713
# Epoch 10/100
# 391/391 [==============================] - 1s 3ms/step - loss: 0.0635 - accuracy: 0.9822 - val_loss: 0.1048 - val_accuracy: 0.9687
# Epoch 11/100
# 391/391 [==============================] - 1s 3ms/step - loss: 0.0575 - accuracy: 0.9835 - val_loss: 0.0977 - val_accuracy: 0.9710
# Epoch 12/100
# 391/391 [==============================] - 1s 3ms/step - loss: 0.0517 - accuracy: 0.9851 - val_loss: 0.1015 - val_accuracy: 0.9705
# Epoch 13/100
# 391/391 [==============================] - 1s 3ms/step - loss: 0.0474 - accuracy: 0.9863 - val_loss: 0.0973 - val_accuracy: 0.9725
# Epoch 14/100
# 391/391 [==============================] - 1s 3ms/step - loss: 0.0427 - accuracy: 0.9880 - val_loss: 0.0959 - val_accuracy: 0.9714
# Epoch 15/100
# 391/391 [==============================] - 1s 3ms/step - loss: 0.0394 - accuracy: 0.9887 - val_loss: 0.0938 - val_accuracy: 0.9726
# Epoch 16/100
# 391/391 [==============================] - 2s 4ms/step - loss: 0.0356 - accuracy: 0.9901 - val_loss: 0.0978 - val_accuracy: 0.9728
# Epoch 17/100
# 391/391 [==============================] - 1s 3ms/step - loss: 0.0317 - accuracy: 0.9920 - val_loss: 0.0948 - val_accuracy: 0.9728
# Epoch 18/100
# 391/391 [==============================] - 1s 3ms/step - loss: 0.0290 - accuracy: 0.9925 - val_loss: 0.0965 - val_accuracy: 0.9719
# Epoch 19/100
# 391/391 [==============================] - 1s 2ms/step - loss: 0.0265 - accuracy: 0.9934 - val_loss: 0.0978 - val_accuracy: 0.9730
# Epoch 20/100
# 391/391 [==============================] - 1s 2ms/step - loss: 0.0241 - accuracy: 0.9941 - val_loss: 0.0998 - val_accuracy: 0.9730
# Epoch 21/100
# 391/391 [==============================] - 1s 2ms/step - loss: 0.0223 - accuracy: 0.9948 - val_loss: 0.1013 - val_accuracy: 0.9733
# Epoch 22/100
# 391/391 [==============================] - 1s 3ms/step - loss: 0.0203 - accuracy: 0.9952 - val_loss: 0.0983 - val_accuracy: 0.9735
# Epoch 23/100
# 391/391 [==============================] - 1s 2ms/step - loss: 0.0186 - accuracy: 0.9957 - val_loss: 0.1022 - val_accuracy: 0.9722
# Epoch 24/100
# 391/391 [==============================] - 1s 2ms/step - loss: 0.0168 - accuracy: 0.9966 - val_loss: 0.1011 - val_accuracy: 0.9733
# Epoch 25/100
# 391/391 [==============================] - 1s 2ms/step - loss: 0.0146 - accuracy: 0.9972 - val_loss: 0.1002 - val_accuracy: 0.9739
# Best epoch: 15
# Epoch 1/18
# 469/469 [==============================] - 1s 2ms/step - loss: 0.4270 - accuracy: 0.8831
# Epoch 2/18
# 469/469 [==============================] - 1s 2ms/step - loss: 0.2063 - accuracy: 0.9420
# Epoch 3/18
# 469/469 [==============================] - 1s 2ms/step - loss: 0.1569 - accuracy: 0.9554
# Epoch 4/18
# 469/469 [==============================] - 1s 2ms/step - loss: 0.1283 - accuracy: 0.9636
# Epoch 5/18
# 469/469 [==============================] - 1s 2ms/step - loss: 0.1098 - accuracy: 0.9681
# Epoch 6/18
# 469/469 [==============================] - 1s 2ms/step - loss: 0.0945 - accuracy: 0.9727
# Epoch 7/18
# 469/469 [==============================] - 1s 2ms/step - loss: 0.0839 - accuracy: 0.9757
# Epoch 8/18
# 469/469 [==============================] - 1s 2ms/step - loss: 0.0737 - accuracy: 0.9786
# Epoch 9/18
# 469/469 [==============================] - 1s 3ms/step - loss: 0.0662 - accuracy: 0.9807
# Epoch 10/18
# 469/469 [==============================] - 1s 2ms/step - loss: 0.0598 - accuracy: 0.9824
# Epoch 11/18
# 469/469 [==============================] - 1s 2ms/step - loss: 0.0541 - accuracy: 0.9843
# Epoch 12/18
# 469/469 [==============================] - 1s 3ms/step - loss: 0.0485 - accuracy: 0.9864
# Epoch 13/18
# 469/469 [==============================] - 1s 2ms/step - loss: 0.0452 - accuracy: 0.9866
# Epoch 14/18
# 469/469 [==============================] - 1s 2ms/step - loss: 0.0401 - accuracy: 0.9884
# Epoch 15/18
# 469/469 [==============================] - 1s 2ms/step - loss: 0.0365 - accuracy: 0.9898
# Epoch 16/18
# 469/469 [==============================] - 1s 2ms/step - loss: 0.0335 - accuracy: 0.9901
# Epoch 17/18
# 469/469 [==============================] - 1s 3ms/step - loss: 0.0300 - accuracy: 0.9918
# Epoch 18/18
# 469/469 [==============================] - 1s 2ms/step - loss: 0.0279 - accuracy: 0.9922
# 313/313 [==============================] - 1s 1ms/step - loss: 0.0860 - accuracy: 0.9754

# %%
best_models = tuner.get_best_models(top_n)

# %%
best_models
# Out:
# [<keras.engine.sequential.Sequential at 0x7f8aa03df040>,
#  <keras.engine.sequential.Sequential at 0x7f8aac178220>,
#  <keras.engine.sequential.Sequential at 0x7f8aa03dcee0>,
#  <keras.engine.sequential.Sequential at 0x7f8aac17a9e0>]
